# %%
from BDFit import StarFit

s = StarFit()

s.color_color(y='IRAC.I2-IRAC.I1', x ='NISP.Y-NISP.J', s=0.1,
                alpha=0.5, filter_by = '(VIS.vis - NISP.Y) > 2',
                color_by='temp')
# Out:
# Library path: /nvme/scratch/work/tharvey/brown_dwarfs/models
# Warning! F410M found in multiple instruments. Keeping first, which is NIRCam. Provide instrument.band in dictionary to override this.
# Total models: 49630
# /nvme/scratch/work/tharvey/brown_dwarfs/src/BDFit/StarFit.py:2322: RuntimeWarning: divide by zero encountered in log10
#   grid_converted = -2.5*np.log10(grid * 1e-9) + 8.9
# /nvme/scratch/work/tharvey/brown_dwarfs/src/BDFit/StarFit.py:2855: RuntimeWarning: invalid value encountered in subtract
#   result = self.operators[op_symbol](left, right)
# (<Figure size 1200x800 with 2 Axes>,
#  <Axes: title={'center': 'Filtered by: (VIS.vis - NISP.Y) > 2'}, xlabel='NISP.Y-NISP.J', ylabel='IRAC.I2-IRAC.I1'>)
